# %%
import pandas as pd

# %% [markdown]
# ### import file

# %%
path=r"C:\Users\Anshu\Desktop\New folder (3)\automation testing notes\project\Pandas\netflix.csv"
df=pd.read_csv(path)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8790 entries, 0 to 8789
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8790 non-null   object
#  1   type          8790 non-null   object
#  2   title         8790 non-null   object
#  3   director      8790 non-null   object
#  4   country       8790 non-null   object
#  5   date_added    8790 non-null   object
#  6   release_year  8790 non-null   int64
#  7   rating        8790 non-null   object
#  8   duration      8790 non-null   object
#  9   listed_in     8790 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 686.8+ KB

# %% [markdown]
# ### checking null value in dataset

# %%
df.isna().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# dtype: int64

# %% [markdown]
# ### Crosscheck null value in dataset

# %%
df[df.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, country, date_added, release_year, rating, duration, listed_in]
# Index: []

# %% [markdown]
# ### Duplicated records in dataset

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Cross check duplicate records in dataset

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, country, date_added, release_year, rating, duration, listed_in]
# Index: []

# %% [markdown]
# ### Chainging the datatype

# %%
df['date_added']=pd.to_datetime(df['date_added'])

# %%
df.dtypes
# Out:
# show_id                 object
# type                    object
# title                   object
# director                object
# country                 object
# date_added      datetime64[ns]
# release_year             int64
# rating                  object
# duration                object
# listed_in               object
# dtype: object

# %% [markdown]
# ### count of types(movies and TV Show)

# %%
df['type'].value_counts()
# Out:
# type
# Movie      6126
# TV Show    2664
# Name: count, dtype: int64

# %%
df[df['type'].duplicated()] #Note :-LOL
# Out:
#      show_id     type                             title         director  \
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# 5         s9  TV Show     The Great British Baking Show  Andy Devonshire
# 6        s10    Movie                      The Starling   Theodore Melfi
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#              country date_added  release_year rating   duration  \
# ...

# %%
df[df['type']=='Movie']
# Out:
#      show_id   type                             title         director  \
# 0         s1  Movie              Dick Johnson Is Dead  Kirsten Johnson
# 3        s14  Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8  Movie                           Sankofa     Haile Gerima
# 6        s10  Movie                      The Starling   Theodore Melfi
# 7       s939  Movie   Motu Patlu in the Game of Zones      Suhas Kadav
# ...      ...    ...                               ...              ...
# 8702   s8232  Movie                          The Bund        Not Given
# 8707   s8269  Movie                  The Darkest Dawn        Not Given
# 8716   s8331  Movie                  The Great Battle        Not Given
# 8763   s8648  Movie       Twisted Trunk, Big Fat Body        Not Given
# 8783   s8785  Movie              Yoko and His Friends        Not Given
#
#              country date_added  release_year rating duration  \
# ...

# %% [markdown]
# ### doing split reusable code i guess :-)
# ### for movie timing and season count

# %%
def split_time(duration):
    return duration.split(' ')[0]
df['movie_duration']=df['duration'].apply(lambda x : split_time(x))

# %%
df['total_season']=df['duration'].apply (lambda x : split_time(x))

# %% [markdown]
# ### Change the datatype of new columns

# %%
df['movie_duration'].astype(int).dtypes  #just to check weather it is converting into int or not :-)
# Out:
# dtype('int32')

# %%
df['movie_duration']=df['movie_duration'].astype(int)

# %%
df['total_season']=df['movie_duration'].astype(int)

# %%
df.dtypes
# Out:
# show_id                   object
# type                      object
# title                     object
# director                  object
# country                   object
# date_added        datetime64[ns]
# release_year               int64
# rating                    object
# duration                  object
# listed_in                 object
# movie_duration             int32
# total_season               int32
# dtype: object

# %%
df
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country date_added  release_year rating   duration  \
# ...

# %% [markdown]
# ### case staement type

# %%
df.loc[df['type']=='Movie','total_season']=0

# %%
df.loc[df['type']=='TV Show','movie_duration']=0

# %% [markdown]
# ### Highest duration movie

# %%
a=df['movie_duration'].max()
df[df['movie_duration']==a]
# Out:
#      show_id   type                       title   director        country  \
# 7822   s4254  Movie  Black Mirror: Bandersnatch  Not Given  United States
#
#       date_added  release_year rating duration  \
# 7822  12/28/2018          2018  TV-MA  312 min
#
#                                            listed_in  movie_duration  \
# 7822  Dramas, International Movies, Sci-Fi & Fantasy             312
#
#       total_season
# 7822             0

# %% [markdown]
# ### Lowest duration will be zero apart from zero which is lowest

# %%
a=df[df['movie_duration']!=0].min()['movie_duration']
df[df['movie_duration']==a]
# Out:
#      show_id   type   title                           director        country  \
# 2820   s3778  Movie  Silent  Limbert Fabian, Brandon Oldenburg  United States
#
#      date_added  release_year rating duration  \
# 2820   6/4/2019          2014   TV-Y    3 min
#
#                                        listed_in  movie_duration  total_season
# 2820  Children & Family Movies, Sci-Fi & Fantasy               3             0

# %% [markdown]
# ### cross checking datetime

# %%
df[df['date_added'].dt.year==2021]
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 6917   s1456  TV Show     Headspace Guide to Meditation        Not Given
# 6918   s1458  TV Show  Jenni Rivera: Mariposa de Barrio        Not Given
# 6920   s1461  TV Show                           Monarca        Not Given
# 6921   s1466  TV Show             The Haunted Hathaways        Not Given
# 6922   s1467    Movie      The Minimalists: Less Is Now        Not Given
#
#             country date_added  release_year rating   duration  \
# ...

# %%
df['date_added'].dt.year.value_counts().reset_index().sort_values('date_added')
# Out:
#     date_added  count
# 12        2008      2
# 11        2009      2
# 13        2010      1
# 8         2011     13
# 10        2012      3
# 9         2013     11
# 7         2014     24
# 6         2015     82
# 5         2016    426
# 4         2017   1185
# 2         2018   1648
# 0         2019   2016
# 1         2020   1879
# 3         2021   1498

# %% [markdown]
# ### renaming columns

# %%
df['show_id']=df['show_id'].replace('s','',regex=True)

# %%
df
# Out:
#      show_id     type                             title         director  \
# 0          1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1          3  TV Show                         Ganglands  Julien Leclercq
# 2          6  TV Show                     Midnight Mass    Mike Flanagan
# 3         14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4          8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785    8797  TV Show                        Yunus Emre        Not Given
# 8786    8798  TV Show                         Zak Storm        Not Given
# 8787    8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788    8784  TV Show                              Yoko        Not Given
# 8789    8786  TV Show                               YOM        Not Given
#
#             country date_added  release_year rating   duration  \
# ...

# %% [markdown]
# ### rename columns

# %%
df.rename(columns={'show_id':'id'},inplace=True)

# %%
df
# Out:
#         id     type                             title         director  \
# 0        1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1        3  TV Show                         Ganglands  Julien Leclercq
# 2        6  TV Show                     Midnight Mass    Mike Flanagan
# 3       14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4        8    Movie                           Sankofa     Haile Gerima
# ...    ...      ...                               ...              ...
# 8785  8797  TV Show                        Yunus Emre        Not Given
# 8786  8798  TV Show                         Zak Storm        Not Given
# 8787  8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788  8784  TV Show                              Yoko        Not Given
# 8789  8786  TV Show                               YOM        Not Given
#
#             country date_added  release_year rating   duration  \
# ...

# %% [markdown]
# ### Drop coumns that not needed now

# %%
df.drop('duration',axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['id', 'type', 'title', 'director', 'country', 'date_added',
#        'release_year', 'rating', 'listed_in', 'movie_duration',
#        'total_season'],
#       dtype='object')

# %% [markdown]
# ### Values in raiting and their count

# %%
df['rating'].unique()
# Out:
# array(['PG-13', 'TV-MA', 'TV-PG', 'TV-14', 'TV-Y7', 'TV-Y', 'PG', 'TV-G',
#        'R', 'G', 'NC-17', 'NR', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
df['rating'].value_counts()
# Out:
# rating
# TV-MA       3205
# TV-14       2157
# TV-PG        861
# R            799
# PG-13        490
# TV-Y7        333
# TV-Y         306
# PG           287
# TV-G         220
# NR            79
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# Name: count, dtype: int64

# %% [markdown]
# ### Country wise content uploaded on netflix

# %%
df['country'].value_counts()
# Out:
# country
# United States     3240
# India             1057
# United Kingdom     638
# Pakistan           421
# Not Given          287
#                   ...
# Iran                 1
# West Germany         1
# Greece               1
# Zimbabwe             1
# Soviet Union         1
# Name: count, Length: 86, dtype: int64

# %%
df.groupby('country')['id'].count().reset_index().sort_values('id',ascending=False)
# Out:
#            country    id
# 80   United States  3240
# 29           India  1057
# 79  United Kingdom   638
# 52        Pakistan   421
# 51       Not Given   287
# ..             ...   ...
# 69    Soviet Union     1
# 53        Paraguay     1
# 58     Puerto Rico     1
# 66         Somalia     1
# 85        Zimbabwe     1
#
# [86 rows x 2 columns]

# %% [markdown]
# ### Country with type count

# %%
filter=df.groupby(['country','rating'])['id'].count().reset_index()
filter[filter['country']=='India']
# Out:
#     country    rating   id
# 137   India        NR    4
# 138   India        PG    4
# 139   India     PG-13    5
# 140   India         R    2
# 141   India     TV-14  574
# 142   India      TV-G    9
# 143   India     TV-MA  266
# 144   India     TV-PG  140
# 145   India      TV-Y   10
# 146   India     TV-Y7   42
# 147   India  TV-Y7-FV    1

# %% [markdown]
# ### contains command

# %%
# df['listed_in'].value_counts()
df[(df['listed_in'].str.contains('Action')) & (df['listed_in'].str.contains('Dramas'))]
# Out:
#         id     type                 title                    director  \
# 56      37    Movie        The Stronghold              Cédric Jimenez
# 57      39    Movie   Birth of the Dragon                George Nolfi
# 60      42    Movie                  Jaws            Steven Spielberg
# 107     85    Movie  Omo Ghetto: the Saga  JJC Skillz, Funke Akindele
# 142    106    Movie      Angamaly Diaries        Lijo Jose Pellissery
# ...    ...      ...                   ...                         ...
# 8512  7126  TV Show               Jericho                   Not Given
# 8611  7730  TV Show    Person of Interest                   Not Given
# 8674  8065  TV Show             Spartacus                   Not Given
# 8702  8232    Movie              The Bund                   Not Given
# 8716  8331    Movie      The Great Battle                   Not Given
#
#             country date_added  release_year rating  \
# 56        Not Given 2021-09-17          2021  TV-MA
# ...

# %%
df['release_year'].value_counts()
# Out:
# release_year
# 2018    1146
# 2017    1030
# 2019    1030
# 2020     953
# 2016     901
#         ...
# 1966       1
# 1959       1
# 1925       1
# 1947       1
# 1961       1
# Name: count, Length: 74, dtype: int64

# %%
df['date_added'].dt.year.value_counts().reset_index()
# Out:
#     date_added  count
# 0         2019   2016
# 1         2020   1879
# 2         2018   1648
# 3         2021   1498
# 4         2017   1185
# 5         2016    426
# 6         2015     82
# 7         2014     24
# 8         2011     13
# 9         2013     11
# 10        2012      3
# 11        2009      2
# 12        2008      2
# 13        2010      1

# %%
df[(df['date_added'].dt.year == 2019) & (df['date_added'].dt.quarter == 3)]
# Out:
#         id     type                                             title  \
# 313   3593  TV Show                                        Happy Jail
# 336   3525  TV Show                                           Top Boy
# 337   3540  TV Show  Loo Loo Kids: Johny & Friends Musical Adventures
# 338   3563  TV Show                                         HERO MASK
# 339   3672  TV Show                                Extreme Engagement
# ...    ...      ...                                               ...
# 8680  8098  TV Show                  Storage Wars: Northern Treasures
# 8703  8244  TV Show                                   The Chefs' Line
# 8706  8263  TV Show                           The Curse of Oak Island
# 8747  8546  TV Show                                      The Universe
# 8757  8601  TV Show                                             Tobot
#
#        director        country date_added  release_year rating  \
# ...

# %%
a=df['date_added'].dt.year
b=df['date_added'].dt.quarter
df.groupby([a,b])['id'].count()
# Out:
# date_added  date_added
# 2008        1               2
# 2009        2               1
#             4               1
# 2010        4               1
# 2011        2               1
#             3               1
#             4              11
# 2012        1               1
#             4               2
# 2013        1               1
#             3               3
#             4               7
# 2014        1               4
#             2               3
#             3               3
#             4              14
# 2015        1              10
#             2              17
#             3              16
#             4              39
# 2016        1              75
#             2              53
#             3             108
#             4             190
# 2017        1             277
#             2             272
#             3             307
#             4             329
# 2018        1             388
#             2             290
# ...

# %%
df_movie=df[df['type']=='Movie']

# %%
df_movie.drop('total_season',axis=1,inplace=True)
# Out:
# C:\Users\Anshu\AppData\Local\Temp\ipykernel_16888\399868966.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_movie.drop('total_season',axis=1,inplace=True)

# %%
# Out:
#         id   type                             title         director  \
# 0        1  Movie              Dick Johnson Is Dead  Kirsten Johnson
# 3       14  Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4        8  Movie                           Sankofa     Haile Gerima
# 6       10  Movie                      The Starling   Theodore Melfi
# 7      939  Movie   Motu Patlu in the Game of Zones      Suhas Kadav
# ...    ...    ...                               ...              ...
# 8702  8232  Movie                          The Bund        Not Given
# 8707  8269  Movie                  The Darkest Dawn        Not Given
# 8716  8331  Movie                  The Great Battle        Not Given
# 8763  8648  Movie       Twisted Trunk, Big Fat Body        Not Given
# 8783  8785  Movie              Yoko and His Friends        Not Given
#
#              country date_added  release_year rating  \
# 0      United States 2021-09-25          2020  PG-13
# ...

# %%
df_movie.to_csv('Movies',index=False)

# %%
df_TV_Show=df[df['type']=='TV Show']

# %%
df_TV_Show.drop('movie_duration',axis=1,inplace=True)
# Out:
# C:\Users\Anshu\AppData\Local\Temp\ipykernel_16888\1632354215.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_TV_Show.drop('movie_duration',axis=1,inplace=True)

# %%
df_TV_Show.to_csv('Series',index=False)

# %%
df_movie['movie_duration'].min()
# Out:
# 3

# %%
df_TV_Show['total_season'].min()
# Out:
# 1
